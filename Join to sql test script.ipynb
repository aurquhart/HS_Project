# %%
# Import libraries
import pandas as pd
import sys
from sqlalchemy import create_engine, MetaData, Table, select, engine
import pyodbc

# %%
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
# Out:
# Python version 3.4.3 |Anaconda 2.3.0 (64-bit)| (default, Mar  6 2015, 12:06:10) [MSC v.1600 64 bit (AMD64)]
# Pandas version 0.16.2

# %%
# Parameters
server = '192.168.1.52'
db = 'naturex'

# Create the connection
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=' + DB['servername'] + ';DATABASE=' + DB['database'] + ';Trusted_Connection=yes')

# query db
sql = """

SELECT top 5 *
FROM dbo.raw_base_0217

"""
df = pandas.io.sql.read_sql(sql, conn)
df.head()
# Out:
#   Customer Type Customer Distribution Channel  \
# 0        Direct               Direct Customer
# 1        Direct               Direct Customer
# 2        Direct               Direct Customer
# 3        Direct               Direct Customer
# 4        Direct               Direct Customer
#
#   Customer Distribution Sub-channel              Customer Group Or Name  \
# 0                          Customer       KERVAN GIDA SAN. VE TIC. A.S.
# 1                          Customer  R & R ICE CREAM (Leeming) UK  LTD
# 2                          Customer  R & R ICE CREAM (Leeming) UK  LTD
# 3                          Customer  R & R ICE CREAM (Leeming) UK  LTD
# 4                          Customer  R & R ICE CREAM (Leeming) UK  LTD
#
#                         Customer Name Customer Code Ship To Country  \
# 0       KERVAN GIDA SAN. VE TIC. A.S.       O411136          TURKEY
# 1  R & R ICE CREAM (Leeming) UK  LTD        O411026            U.K.
# 2  R & R ICE CREAM (Leeming) UK  LTD        O411026            U.K.
# 3  R & R ICE CREAM (Leeming) UK  LTD        O411026            U.K.
# 4  R & R ICE CREAM (Leeming) UK  LTD        O411026            U.K.
#
#   Ship to State                    Ship To City Ship To Zip Code ...  \
# 0          None             BEYLIKDUZU ISTANBUL            34524 ...
# 1          None  NORTHALLERTON, North Yorkshire          DL7 9UL ...
# 2          None  NORTHALLERTON, North Yorkshire          DL7 9UL ...
# 3          None  NORTHALLERTON, North Yorkshire          DL7 9UL ...
# 4          None  NORTHALLERTON, North Yorkshire          DL7 9UL ...
#
#   Sales Agreement Currency Sales Agreement Incoterm Name  \
# 0                      EUR                           EXW
# 1                      GBP                           DDP
# 2                      GBP                           DDP
# 3                      GBP                           DDP
# 4                      GBP                           DDP
#
#   Sales Agreement Country Zone Sales Agreement Country Group  \
# 0                         EMEA      EUROPE (OTHER COUNTRIES)
# 1                         EMEA                EUROPEAN UNION
# 2                         EMEA                EUROPEAN UNION
# 3                         EMEA                EUROPEAN UNION
# 4                         EMEA                EUROPEAN UNION
#
#   Sales Agreement Country Name Company Code Company Name Invoice Incoterm  \
# 0                       TURKEY           OO  Naturex Ltd              EXW
# 1                         U.K.           OO  Naturex Ltd              DDP
# 2                         U.K.           OO  Naturex Ltd              DDP
# 3                         U.K.           OO  Naturex Ltd              DDP
# 4                         U.K.           OO  Naturex Ltd              DDP
#
#   YearMonth ID
# 0      None  1
# 1      None  4
# 2      None  5
# 3      None  6
# 4      None  8
#
# [5 rows x 81 columns]

# %%
df.dtypes
# Out:
# Customer Type                              object
# Customer Distribution Channel              object
# Customer Distribution Sub-channel          object
# Customer Group Or Name                     object
# Customer Name                              object
# Customer Code                              object
# Ship To Country                            object
# Ship to State                              object
# Ship To City                               object
# Ship To Zip Code                           object
# Ship To Address Line 1                     object
# Ship To Address Line 2                     object
# Ship To Code                               object
# Customer Bussiness Unit                    object
# Customer Activity 1                        object
# Customer Activity 2                        object
# Customer Status                            object
# Invoice Date Name                          object
# Invoice Date                               object
# Invoice Code                               object
# Invoice Line Number                       float64
# Product Business Unit Name                 object
# Product Effective Product Line             object
# Product Effective Product Line Name        object
# Product Effective Product Subline Name     object
# Product Common Name                        object
# Product Form Name                          object
# Product Name                               object
# Product Ref                                object
# Master Ref# Name                           object
#                                            ...
# Quantity                                  float64
# Sales In USD                              float64
# Sales In EUR                              float64
# Current Margin In EUR                     float64
# Current Margin In USD                     float64
# Historical Margin In EUR                  float64
# Historical Margin In USD                  float64
# Current Unit Cost In EUR                  float64
# Historical Unit Cost In EUR               float64
# Current Unit Cost In USD                  float64
# Historical Unit Cost In USD               float64
# Unit Price In USD                         float64
# Unit Price In EUR                         float64
# Unit Price In Transactionnal Currency     float64
# Sales In TCY                              float64
# Transactional Currency                     object
# Local Currency                             object
# Sales Agreement                           float64
# Sales Agreement EXW                       float64
# Sales Agreement Transport                 float64
# Sales Agreement Currency                   object
# Sales Agreement Incoterm Name              object
# Sales Agreement Country Zone               object
# Sales Agreement Country Group              object
# Sales Agreement Country Name               object
# Company Code                               object
# Company Name                               object
# Invoice Incoterm                           object
# YearMonth                                  object
# ID                                          int64
# dtype: object
